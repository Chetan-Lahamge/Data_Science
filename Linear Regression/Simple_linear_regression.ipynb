# %% [markdown]
# ### Import Necessary Libraries

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### Read/Import the data

# %%
news_paper_data = pd.read_csv('NewspaperData.csv')

# %% [markdown]
# ### Initial Analysis

# %%
news_paper_data.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
news_paper_data.isna().sum()
# Out:
# Newspaper    0
# daily        0
# sunday       0
# dtype: int64

# %%
news_paper_data.dtypes
# Out:
# Newspaper     object
# daily        float64
# sunday       float64
# dtype: object

# %% [markdown]
# ### Assuptions Check

# %% [markdown]
# #### 1. Check for linearity

# %%
sns.scatterplot(x='daily', y='sunday', data=news_paper_data)
plt.title('Sunday Vs Daily Paper Circulation')
plt.show()

# %%
sns.lmplot(data=news_paper_data,x='daily',y='sunday')
plt.title('Sunday Vs Daily Paper Circulation')
plt.show()

# %% [markdown]
# ### 2. Homoscedasticity - It can be checked post model building and training

# %% [markdown]
# ### 3. No Multicolinearity - Condition Satisfied

# %% [markdown]
# ### 4. No Auto Regression - Condition Satisfied

# %% [markdown]
# ### 5. Zero residual mean - It can be checked post model building and training

# %% [markdown]
# ## Data Preparation

# %%
news_paper_data.head()
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
del news_paper_data['Newspaper']

# %%
news_paper_data.head()
# Out:
#      daily   sunday
# 0  391.952  488.506
# 1  516.981  798.298
# 2  355.628  235.084
# 3  238.555  299.451
# 4  537.780  559.093

# %% [markdown]
# ## Model Building | Model Training
#
# For Linear Regression, we can use 2 libraries.
# - 1. statsmodels - ols technique (Ordinary Least Square Technique)
# - 2. sklearn - LinearRegression

# %% [markdown]
# #### Model Building

# %%
import statsmodels.formula.api as smf

# %%
lin_reg_model = smf.ols(formula='sunday~daily',data = news_paper_data).fit()

# %%
lin_reg_model.params
# Out:
# Intercept    13.835630
# daily         1.339715
# dtype: float64

# %% [markdown]
# y = mx+c
#
# where
# m = slope
# x = independant feature
# c = intercept

# %%
x = 200

# %%
(1.339715*x )+13.835630
# Out:
# 281.77862999999996

# %%
x1 = 391.952	
actual_y = 488.506

# %%
(1.339715 * x1) + 13.835630
# Out:
# 538.93960368

# %%
488.506 - 538.93960368
# Out:
# -50.43360368000003

# %%
news_paper_data.shape
# Out:
# (34, 2)
