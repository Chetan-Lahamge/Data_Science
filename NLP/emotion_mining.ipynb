# %%
import numpy as np
import pandas as pd
import string
import spacy
from matplotlib.pyplot import imread
from matplotlib import pyplot as plt
from wordcloud import WordCloud
# %matplotlib inline

# %%
book = pd.read_csv("C:/Users/Chetan/Downloads/apple.txt",sep='\t')

# %%
## Sentiment analysis
afinn = pd.read_csv('Afinn.csv', sep=',', encoding='latin-1')
afinn.shape
# Out:
# (2477, 2)

# %%
afinn.sort_values('value',ascending=False).head(10)
# Out:
#               word  value
# 2179        superb      5
# 2234      thrilled      5
# 1648   outstanding      5
# 1226        hurrah      5
# 315   breathtaking      5
# 2429        winner      4
# 1500  masterpieces      4
# 1089       godsend      4
# 2428           win      4
# 320      brilliant      4

# %%
afinn['value'].max(), afinn['value'].min()
# Out:
# (5, -5)

# %%
book = [x.strip() for x in book.x] # removing extra spaces
book = [x for x in book if x] # removes empty strings, because they are considered in python as false
book[0:10]
# Out:
# ["It's amazing..... battery last around 10 -12 hrs.....best laptop for students and coders",
# ...

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Chetan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# doc = ["It s amazing battery last around 10 12 hrs"]
# word_tokenizer = ["it","s","amazing","battery","last","around","10","12","hrs"]
# sentence_tokenizer = ["It s amazing battery last around 10 12 hrs"]

# %%
from nltk import tokenize
sentences = tokenize.sent_tokenize(" ".join(book))
sentences[5:15]
# Out:
# ['!',
#  '), all printers are not compatible (e.g.',
#  "the most economical MFD laser printer RICOH SP 111 can't be used), huge compatibility issues with Pages (MS Word) and Keynote (powerpoint) unless you master it by working on these (still mostly the document and slides either do not open in windows environment or have distortion issues).",
#  'you need to spend extra for an external CD writer and tp buy a carry bag.',
#  'Mac con not be connected to most of the projectors unless you buy some connectors, which are expensive and theres no clarity which one to buy and from where.',
#  "you can't connect it to your TV, the ports are different and again theres no clarity - customer support, manuals or help section are silent !",
#  'Marketing strategy for Indian market, if at all has been planned, has been very bad.',
#  'If these critical issues (and a few more not mentioned here) are handled properly, the Mac can sweep away other laptops in India.',
# ...

# %%
sent_df = pd.DataFrame(sentences, columns=['sentence'])
sent_df
# Out:
#                                               sentence
# 0    It's amazing..... battery last around 10 -12 h...
# 1                        Got it in 50k in Diwali sale.
# 2    Technically good laptop.Good News.luxury produ...
# 3       Terrific sense of possession & pride.Bad News.
# 4    Problems will be there if you are switching fr...
# ..                                                 ...
# 210  You can get one of the best movie experiences ...
# 211                        Overall I would it a 4.5/5.
# 212  I got a great deal on this laptop, which I hav...
# 213  I got it not only on discount but also was abl...
# 214  Laptop works really well, it was a good purchase!
#
# [215 rows x 1 columns]

# %%
affinity_scores = afinn.set_index('word')['value'].to_dict()
affinity_scores
# Out:
# {'abandon': -2,
#  'abandoned': -2,
#  'abandons': -2,
#  'abducted': -2,
#  'abduction': -2,
#  'abductions': -2,
#  'abhor': -3,
#  'abhorred': -3,
#  'abhorrent': -3,
#  'abhors': -3,
#  'abilities': 2,
#  'ability': 2,
#  'aboard': 1,
#  'absentee': -1,
#  'absentees': -1,
#  'absolve': 2,
#  'absolved': 2,
#  'absolves': 2,
#  'absolving': 2,
#  'absorbed': 1,
#  'abuse': -3,
#  'abused': -3,
#  'abuses': -3,
#  'abusive': -3,
#  'accept': 1,
#  'accepted': 1,
#  'accepting': 1,
#  'accepts': 1,
#  'accident': -2,
#  'accidental': -2,
#  'accidentally': -2,
#  'accidents': -2,
#  'accomplish': 2,
#  'accomplished': 2,
#  'accomplishes': 2,
#  'accusation': -2,
#  'accusations': -2,
#  'accuse': -2,
#  'accused': -2,
#  'accuses': -2,
#  'accusing': -2,
#  'ache': -2,
#  'achievable': 1,
#  'aching': -2,
#  'acquit': 2,
#  'acquits': 2,
#  'acquitted': 2,
#  'acquitting': 2,
#  'acrimonious': -3,
#  'active': 1,
#  'adequate': 1,
#  'admire': 3,
#  'admired': 3,
#  'admires': 3,
# ...

# %%
## Custom function: score each word in a sentence in lemmatised form, but calculate the score for the whole original sentence.

nlp = spacy.load('en_core_web_md')
sentiment_lexicon = affinity_scores

def calculate_sentiment (text: str = None):
	sent_score = 0
	if text:
		sentence = nlp(text)
		print(sentence)
		for word in sentence:
			sent_score += sentiment_lexicon.get(word.lemma_,0)
	return sent_score

# %%
# Test that it works
calculate_sentiment(text = 'Amazed')
# Out:
# Amazed
# 2

# %%
sent_df['sentiment_value'] = sent_df['sentence'].apply(calculate_sentiment)
# Out:
# It's amazing..... battery last around 10 -12 hrs.....best laptop for students and coders Finally a MacBook possession.
# Got it in 50k in Diwali sale.
# Technically good laptop.Good News.luxury product, niche technology, good battery life, reliable machine (other laptops crash and become defunct in 6-10 years), no anti-virus required, security of data and transactions much better.
# Terrific sense of possession & pride.Bad News.
# Problems will be there if you are switching from windows based system - very less space in hard disk, no CD drive, inability to transfer data from Mac to your existing external hard disc unless you format it, apps are mostly paid and re unreasonably expensive (no free apps which are available otherwise on google play store, even the angry bird costs Rs 400 !
# !
# ), all printers are not compatible (e.g.
# ...

# %%
sent_df['sentiment_value'].min()
# Out:
# -11

# %%
sent_df.head()
# Out:
#                                             sentence  sentiment_value
# 0  It's amazing..... battery last around 10 -12 h...                7
# 1                      Got it in 50k in Diwali sale.                0
# 2  Technically good laptop.Good News.luxury produ...                5
# 3     Terrific sense of possession & pride.Bad News.                4
# 4  Problems will be there if you are switching fr...              -11

# %%
sent_df[sent_df['sentiment_value']>1].sort_values('sentiment_value',ascending=False)
# Out:
#                                               sentence  sentiment_value
# 114  All are Gud.. For now.. Apple,apple,apple, tha...               24
# 32   Basically i will be comparing this with a regu...               20
# 179  ..So now I m working with the external keyboar...               17
# 0    It's amazing..... battery last around 10 -12 h...                7
# 87   I use this for music production and it works a...                7
# ..                                                 ...              ...
# 126  Thank You if you read the whole review because...                2
# 125  While exporting the 4k60fps video the CPU and ...                2
# 123  For hard-core video editing I would recommend ...                2
# 103                          Amazon also did not help.                2
# 113  I used the laptop very carefully but I think A...                2
#
# [82 rows x 2 columns]

# %%
sent_df[sent_df['sentiment_value']<0].sort_values('sentiment_value',ascending=True)
# Out:
#                                               sentence  sentiment_value
# 4    Problems will be there if you are switching fr...              -11
# 176  This is the worst  apple product I have ever s...               -8
# 117  ?, god damn it apple (Though its not bad, have...               -6
# 77   I m stuck with a dead mac after using it for 1...               -5
# 203  The device never had any accidental drop or sh...               -5
# 149  Requires power input to restart again.Contacte...               -4
# 159  From past 1 week I am not able to turn on my m...               -4
# 96   They told me that the motherboard is dead and ...               -3
# 90   Again MacBook start acting dead after 6 more m...               -3
# 142  The hard disk is too small but if you carry an...               -3
# 165             It again got dead and woulnt turn onn.               -3
# 180  From the very beginning the battery life was h...               -3
# ...

# %%
sent_df[(sent_df['sentiment_value']==0)& (sent_df['sentiment_value']==1)].sort_values('sentiment_value',ascending=True)
# Out:
# Empty DataFrame
# Columns: [sentence, sentiment_value]
# Index: []
